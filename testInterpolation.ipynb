# %%
import osiris_utils as ou
import numpy as np

# %%
sim_xx = ou.Simulation("/home/exxxx5/Tese/Decks/ComparePushers/test_drift_calculatinos/interpolation2d/XX/Boris_1.in")
sim_xx_centered = ou.FieldCentering_Simulation(sim_xx)

# %%
print("x1")
print(sim_xx["part_b1"][0][0, 20], sim_xx["part_b2"][0][0, 20], sim_xx["part_b3"][0][0, 20])
print(sim_xx_centered["part_b1"][0][0, 20], sim_xx_centered["part_b2"][0][0, 20], sim_xx_centered["part_b3"][0][0, 20])
# Out:
# x1
# 0.25 0.5 0.5
# 0.25 0.25 0.25
