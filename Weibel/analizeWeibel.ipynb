# %%
import osiris_utils as utils
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import matplotlib as mpl
import pandas as pd
from tqdm import tqdm
plt.rcParams['font.size'] = 13

# %%
utils.time_estimation(40**3, 8**3, 0.3e-6, 50./0.288, 6, hours=False)

# %%
shot = "000250"
#shot = "000350"

species = "neg_electrons"

# %%
# read data no test electrons

folder_path = Path("/home/exxxx5/Tese/Decks/Weibel/Weibel/")

neg_el_noTest = utils.OsirisGridFile(
    folder_path / ("MS/DENSITY/" + species + "/charge/charge-" + species +"-" + shot + ".h5")
    )

e1_noTest = utils.OsirisGridFile(
    folder_path / ("MS/FLD/b1/b1-" + shot + ".h5")
    )

b2_noTest = utils.OsirisGridFile(
    folder_path / ("MS/FLD/b2/b2-" + shot + ".h5")
    )

b3_noTest = utils.OsirisGridFile(
    folder_path / ("MS/FLD/b3/b3-" + shot + ".h5")
    )

e1_noTest = utils.OsirisGridFile(
    folder_path / ("MS/FLD/e1/e1-" + shot + ".h5")
    )

e2_noTest = utils.OsirisGridFile(
    folder_path / ("MS/FLD/e2/e2-" + shot + ".h5")
    )

e3_noTest = utils.OsirisGridFile(
    folder_path / ("MS/FLD/e3/e3-" + shot + ".h5")
    )

# %%
# read data 8ppc

folder_path = Path("/home/exxxx5/Tese/Decks/Weibel/WeibelTestElectrons/")

neg_el = utils.OsirisGridFile(
    folder_path / ("MS/DENSITY/" + species + "/charge/charge-" + species +"-" + shot + ".h5")
    )

b1 = utils.OsirisGridFile(
    folder_path / ("MS/FLD/b1/b1-" + shot + ".h5")
    )

b2 = utils.OsirisGridFile(
    folder_path / ("MS/FLD/b2/b2-" + shot + ".h5")
    )

b3 = utils.OsirisGridFile(
    folder_path / ("MS/FLD/b3/b3-" + shot + ".h5")
    )

e1 = utils.OsirisGridFile(
    folder_path / ("MS/FLD/e1/e1-" + shot + ".h5")
    )

e2 = utils.OsirisGridFile(
    folder_path / ("MS/FLD/e2/e2-" + shot + ".h5")
    )

e3 = utils.OsirisGridFile(
    folder_path / ("MS/FLD/e3/e3-" + shot + ".h5")
    )

# %%
# read data 1ppc

folder_path_1ppc = Path("/home/exxxx5/Tese/Decks/Weibel/WeibelTestElectrons1ppc/")

neg_el_1ppc = utils.OsirisGridFile(
    folder_path_1ppc / ("MS/DENSITY/" + species + "/charge/charge-" + species +"-" + shot + ".h5")
    )

b1_1ppc = utils.OsirisGridFile(
    folder_path_1ppc / ("MS/FLD/b1/b1-" + shot + ".h5")
    )

b2_1ppc = utils.OsirisGridFile(
    folder_path_1ppc / ("MS/FLD/b2/b2-" + shot + ".h5")
    )

b3_1ppc = utils.OsirisGridFile(
    folder_path_1ppc / ("MS/FLD/b3/b3-" + shot + ".h5")
    )

e1_1ppc = utils.OsirisGridFile(
    folder_path_1ppc / ("MS/FLD/e1/e1-" + shot + ".h5")
    )

e2_1ppc = utils.OsirisGridFile(
    folder_path_1ppc / ("MS/FLD/e2/e2-" + shot + ".h5")
    )

e3_1ppc = utils.OsirisGridFile(
    folder_path_1ppc / ("MS/FLD/e3/e3-" + shot + ".h5")
    )

# %%
# read data B0=0.01

folder_path_B0_01 = Path("/home/exxxx5/Tese/Decks/Weibel/WeibelTestElectronsB0_01/")

neg_el_B0_01 = utils.OsirisGridFile(
    folder_path_B0_01 / ("MS/DENSITY/" + species + "/charge/charge-" + species +"-" + shot + ".h5")
    )

b1_B0_01 = utils.OsirisGridFile(
    folder_path_B0_01 / ("MS/FLD/b1/b1-" + shot + ".h5")
    )

b2_B0_01 = utils.OsirisGridFile(
    folder_path_B0_01 / ("MS/FLD/b2/b2-" + shot + ".h5")
    )

b3_B0_01 = utils.OsirisGridFile(
    folder_path_B0_01 / ("MS/FLD/b3/b3-" + shot + ".h5")
    )

e1_B0_01 = utils.OsirisGridFile(
    folder_path_B0_01 / ("MS/FLD/e1/e1-" + shot + ".h5")
    )

e2_B0_01 = utils.OsirisGridFile(
    folder_path_B0_01 / ("MS/FLD/e2/e2-" + shot + ".h5")
    )

e3_B0_01 = utils.OsirisGridFile(
    folder_path_B0_01 / ("MS/FLD/e3/e3-" + shot + ".h5")
    )

# %%
# read data B0=0.1

folder_path_B0_1 = Path("/home/exxxx5/Tese/Decks/Weibel/WeibelTestElectronsB0_1/")

neg_el_B0_1 = utils.OsirisGridFile(
    folder_path_B0_1 / ("MS/DENSITY/" + species + "/charge/charge-" + species +"-" + shot + ".h5")
    )

b1_B0_1 = utils.OsirisGridFile(
    folder_path_B0_1 / ("MS/FLD/b1/b1-" + shot + ".h5")
    )

b2_B0_1 = utils.OsirisGridFile(
    folder_path_B0_1 / ("MS/FLD/b2/b2-" + shot + ".h5")
    )

b3_B0_1 = utils.OsirisGridFile(
    folder_path_B0_1 / ("MS/FLD/b3/b3-" + shot + ".h5")
    )

e1_B0_1 = utils.OsirisGridFile(
    folder_path_B0_1 / ("MS/FLD/e1/e1-" + shot + ".h5")
    )

e2_B0_1 = utils.OsirisGridFile(
    folder_path_B0_1 / ("MS/FLD/e2/e2-" + shot + ".h5")
    )

e3_B0_1 = utils.OsirisGridFile(
    folder_path_B0_1 / ("MS/FLD/e3/e3-" + shot + ".h5")
    )

# %%
# read data B0=1

folder_path_B1 = Path("/home/exxxx5/Tese/Decks/Weibel/WeibelTestElectronsB1/")

neg_el_B1 = utils.OsirisGridFile(
    folder_path_B1 / ("MS/DENSITY/" + species + "/charge/charge-" + species +"-" + shot + ".h5")
    )

b1_B1 = utils.OsirisGridFile(
    folder_path_B1 / ("MS/FLD/b1/b1-" + shot + ".h5")
    )

b2_B1 = utils.OsirisGridFile(
    folder_path_B1 / ("MS/FLD/b2/b2-" + shot + ".h5")
    )

b3_B1 = utils.OsirisGridFile(
    folder_path_B1 / ("MS/FLD/b3/b3-" + shot + ".h5")
    )

e1_B1 = utils.OsirisGridFile(
    folder_path_B1 / ("MS/FLD/e1/e1-" + shot + ".h5")
    )

e2_B1 = utils.OsirisGridFile(
    folder_path_B1 / ("MS/FLD/e2/e2-" + shot + ".h5")
    )

e3_B1 = utils.OsirisGridFile(
    folder_path_B1 / ("MS/FLD/e3/e3-" + shot + ".h5")
    )

# %%
# Histograms

def plotHist(path, shot, key, ax):
    species="test_electrons"
    raw_data = utils.OsirisRawFile(
        path / ("MS/RAW/" + species + "/RAW-" + species + "-" + shot + ".h5")
        )
    
    counts, bins = np.histogram(raw_data.data[key], bins=500)
    bin_centers = (bins[:-1] + bins[1:]) / 2

    bin_widths = bins[1:] - bins[:-1]
  
    # Normalize the counts by the bin width to ensure the same area
    normalized_counts = counts / bin_widths

    ax.plot(
        bin_centers, normalized_counts, 
        label=(r"$t={:.2f}$".format(raw_data.time[0]) + r"$\  [{}]$".format(raw_data.time[1]))
        )
    ax.set_xlabel(r"${}$".format(raw_data.axis[key]["long_name"]) + r"$\  [{}]$".format(raw_data.axis[key]["units"]))
    ax.legend()
    return ax

def compare_hists(path1, path2, key):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
    ax1 = plotHist(path1, "000350", key, ax1)
    ax2 = plotHist(path2, "000350", key, ax2)

    ax1 = plotHist(path1, "000380", key, ax1)
    ax2 = plotHist(path2, "000380", key, ax2)

    ax1 = plotHist(path1, "000410", key, ax1)
    ax2 = plotHist(path2, "000410", key, ax2)

    ax1 = plotHist(path1, "000440", key, ax1)
    ax2 = plotHist(path2, "000440", key, ax2)

    ax1 = plotHist(path1, "000470", key, ax1)
    ax2 = plotHist(path2, "000470", key, ax2)

    ax1 = plotHist(path1, "000500", key, ax1)
    ax2 = plotHist(path2, "000500", key, ax2)

    return ax1, ax2

# %%
# Compare 1ppc and 8ppc

ax1, ax2 = compare_hists(folder_path, folder_path_1ppc, "ene")
ax1.set_xlim(0, 0.001)
ax1.set_ylim(0, 0.012e12)
ax2.set_xlim(0, 0.001)
ax2.set_ylim(0, 0.012e12)
ax1.set_title("8ppc")
ax2.set_title("1ppc")
plt.show()

ax1, ax2 = compare_hists(folder_path, folder_path_1ppc,"p1")
ax1.set_xlim(0, 0.1)
ax1.set_ylim(0, 0.12e9)
ax2.set_xlim(0, 0.1)
ax2.set_ylim(0, 0.12e9)
ax1.set_title("8ppc")
ax2.set_title("1ppc")
plt.show()

# %%
# field and charge maps

def plot(data):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

    # Plot for the first subplot
    im1 = ax1.imshow(data.data[:,:,40].T, aspect="auto", origin="lower", cmap="Reds", extent=[data.grid[0][0], data.grid[0][1], data.grid[1][0], data.grid[1][1]])
    cbar1 = fig.colorbar(im1, ax=ax1)
    cbar1.set_label(r"${}$".format(data.label) + r"$\  [{}]$".format(data.units))
    ax1.set_title(r"$t={:.2f}$".format(data.time[0]) + r"$\  [{}]$".format(data.time[1]))
    ax1.set_xlabel(r"${}$".format(data.axis[0]["long_name"]) + r"$\  [{}]$".format(data.axis[0]["units"]))
    ax1.set_ylabel(r"${}$".format(data.axis[1]["long_name"]) + r"$\  [{}]$".format(data.axis[1]["units"]))

    # Plot for the second subplot
    im2 = ax2.imshow(data.data[40,:,:].T, aspect="auto", origin="lower", cmap="Reds", extent=[data.grid[1][0], data.grid[1][1], data.grid[2][0], data.grid[2][1]])
    cbar2 = fig.colorbar(im2, ax=ax2)
    cbar2.set_label(r"${}$".format(data.label) + r"$\  [{}]$".format(data.units))
    ax2.set_title(r"$t={:.2f}$".format(data.time[0]) + r"$\  [{}]$".format(data.time[1]))
    ax2.set_xlabel(r"${}$".format(data.axis[1]["long_name"]) + r"$\  [{}]$".format(data.axis[1]["units"]))
    ax2.set_ylabel(r"${}$".format(data.axis[2]["long_name"]) + r"$\  [{}]$".format(data.axis[2]["units"]))

    return fig, ax1, ax2

# %%
fig, ax = plt.subplots()

# Plot for the subplot
im = ax.imshow((b3.data[:,:,40]-b3_B0_01.data[:,:,40]).T, aspect="auto", origin="lower", cmap="Reds", extent=[b3.grid[0][0], b3.grid[0][1], b3.grid[1][0], b3.grid[1][1]])

# Add colorbar
cbar = fig.colorbar(im, ax=ax)

plt.show()

# %%
# field and charge maps

# fig, ax1, ax2 = plot(b3)
# fig.suptitle("No test electrons")
# plt.tight_layout()
# plt.show()

fig, ax1, ax2 = plot(b3)
fig.suptitle(r"$B_{1init} = 0$" + r"$\  [{}]$".format(b3.units))
plt.tight_layout()
plt.show()

fig, ax1, ax2 = plot(b3_B0_01)
fig.suptitle(r"$B_{1init} = 0.01$" + r"$\  [{}]$".format(b3_B0_01.units))
plt.tight_layout()
plt.show()

fig, ax1, ax2 = plot(b3_B0_1)
fig.suptitle(r"$B_{1init} = 0.1$" + r"$\  [{}]$".format(b3_B0_1.units))
plt.tight_layout()
plt.show()

fig, ax1, ax2 = plot(b3_B1)
fig.suptitle(r"$B_{1init} = 1$" + r"$\  [{}]$".format(b3_B1.units))
plt.tight_layout()
plt.show()

# %%
# B1, B3 profile

ax = plt.subplot()
x = np.linspace(b1.grid[0][0], b1.grid[0][1], b1.nx[0])
ax.plot(x, b1.data[:,40,40], label = "8ppc", marker='o')
ax.plot(x, b1_1ppc.data[:,40,40], label = "1ppc", marker='o')
ax.plot(x, b1_B0_01.data[:,40,40], label = "B0=0.01", marker='o')
ax.plot(x, b1_B0_1.data[:,40,40], label = "B0=0.1", marker='o')
ax.set_title(r"$t={:.2f}$".format(b1.time[0]) + r"$\  [{}]$".format(b3.time[1]))
ax.set_ylabel(r"${}$".format(b1.label) + r"$\  [{}]$".format(b3.units))
ax.set_xlabel(r"${}$".format(b1.axis[0]["long_name"]) + r"$\  [{}]$".format(b3.axis[0]["units"]))
ax.legend()
plt.show()

ax = plt.subplot()
x = np.linspace(b3.grid[0][0], b3.grid[0][1], b3.nx[0])
ax.plot(x, b3.data[:,40,40], label = "8ppc", marker='o')
ax.plot(x, b3_1ppc.data[:,40,40], label = "1ppc", marker='o')
ax.plot(x, b3_B0_01.data[:,40,40], label = "B0=0.01", marker='o')
ax.plot(x, b3_B0_1.data[:,40,40], label = "B0=0.1", marker='o')
ax.set_title(r"$t={:.2f}$".format(b3.time[0]) + r"$\  [{}]$".format(b3.time[1]))
ax.set_ylabel(r"${}$".format(b3.label) + r"$\  [{}]$".format(b3.units))
ax.set_xlabel(r"${}$".format(b3.axis[0]["long_name"]) + r"$\  [{}]$".format(b3.axis[0]["units"]))
ax.legend()
plt.show()

# %%
# Energy plots

# Define column names based on the header
column_names = ['Iter', 'Time', 'B1', 'B2', 'B3', 'E1', 'E2', 'E3']

# Read the data file
fields = pd.read_csv(folder_path / 'HIST/fld_ene'
                   , sep=r'\s+', skiprows=2, names=column_names)

fields_1ppc = pd.read_csv(folder_path_1ppc / 'HIST/fld_ene'
                   , sep=r'\s+', skiprows=2, names=column_names)

fields_B0_01 = pd.read_csv(folder_path_B0_01 / 'HIST/fld_ene'
                   , sep=r'\s+', skiprows=2, names=column_names)

fields_B0_1 = pd.read_csv(folder_path_B0_1 / 'HIST/fld_ene'
                   , sep=r'\s+', skiprows=2, names=column_names)

fields_B1 = pd.read_csv(folder_path_B1 / 'HIST/fld_ene'
                   , sep=r'\s+', skiprows=2, names=column_names)

column_names2 = [' Iter', 'Time', 'Total Par.', 'Kin. Energy']

ene = pd.read_csv(folder_path / 'HIST/par05_ene'
                   , sep=r'\s+', skiprows=2, names=column_names2)
ene_1ppc = pd.read_csv(folder_path_1ppc / 'HIST/par05_ene'
                   , sep=r'\s+', skiprows=2, names=column_names2)
ene_B0_01  = pd.read_csv(folder_path_B0_01 / 'HIST/par05_ene'
                   , sep=r'\s+', skiprows=2, names=column_names2)
ene_B0_1  = pd.read_csv(folder_path_B0_1 / 'HIST/par05_ene'
                   , sep=r'\s+', skiprows=2, names=column_names2)
ene_B1  = pd.read_csv(folder_path_B1 / 'HIST/par05_ene'
                   , sep=r'\s+', skiprows=2, names=column_names2)

ax = plt.subplot()

ax.plot(ene['Time'], ene['Kin. Energy'], label = "8ppc")
ax.plot(ene_1ppc['Time'], ene_1ppc['Kin. Energy'], label = "1ppc")
ax.plot(ene_B0_01['Time'], ene_B0_01['Kin. Energy'], label = "B0=0.01")
ax.plot(ene_B0_1['Time'], ene_B0_1['Kin. Energy'], label = "B0=0.1")
ax.plot(ene_B1['Time'], ene_B1['Kin. Energy'], label = "B0=1")
ax.set_xlabel("t")
ax.set_xlim(50, 70)
ax.set_ylabel("Kin. Energy")
#ax.set_ylim(1e-6, 2e-5)
ax.legend()
plt.yscale('log')
plt.show()

# ax = plt.subplot()
# sum = fields['Time']*0.
# for label in ['B1', 'B2', 'B3']:
#     ax.plot(fields['Time'], fields[label]**2, label=label+r"$^2$")
#     sum += fields[label]**2
# ax.plot(fields['Time'], sum, label="$B^2$")

# ax.plot(fields['Time'], 1*np.exp(2*0.4*fields['Time']))
# ax.legend()
# ax.set_xlabel("t")
# ax.set_ylabel("fld_ene")

# plt.yscale('log')
# plt.show()

# ax = plt.subplot()
# sum = fields['Time']*0.
# for label in ['E1', 'E2', 'E3']:
#     ax.plot(fields['Time'], fields[label]**2, label=label+r"$^2$")
#     sum += fields[label]**2
# ax.plot(fields['Time'], sum, label="$E^2$")
# ax.legend()
# ax.set_xlabel("t")
# ax.set_ylabel("fld_ene")
# plt.yscale('log')
# plt.show()

# %%
ax = plt.subplot()
#ax.plot(fields['Time'], fields["B1"]**2 + fields["B2"]**2 + fields["B3"]**2, label="8ppc")
#ax.plot(fields_1ppc['Time'], fields_1ppc["B1"]**2 + fields_1ppc["B2"]**2 + fields_1ppc["B3"]**2, label="1ppc")
ax.plot(fields_B0_01['Time'], fields_B0_01["B1"]**2 + fields_B0_01["B2"]**2 + fields_B0_01["B3"]**2, label="B0=0.01")
#ax.plot(fields_B0_1['Time'], fields_B0_1["B1"]**2 + fields_B0_1["B2"]**2 + fields_B0_1["B3"]**2, label="B0=0.1")
#ax.plot(fields_B1['Time'], fields_B1["B1"]**2 + fields_B1["B2"]**2 + fields_B1["B3"]**2, label="B0=1")

#ax.plot(fields['Time'][0:200], 1*np.exp(2*0.4*fields['Time'])[0:200], label=r"$1*e^{(2*0.4*t)}$")
ax.set_title(r"$B^2$")
ax.legend()
ax.set_xlabel("t")
ax.set_ylabel("fld_ene")
ax.grid()
plt.yscale('log')
plt.show()

for label in ['B1', 'B2', 'B3', 'E1', 'E2', 'E3']:
    ax = plt.subplot()
    ax.plot(fields['Time'], fields[label]**2, label="8ppc")
    ax.plot(fields_1ppc['Time'], fields_1ppc[label]**2, label="1ppc")

    ax.plot(fields_B0_01['Time'], fields_B0_01[label]**2, label="B0=0.01")
    ax.plot(fields_B0_1['Time'], fields_B0_1[label]**2, label="B0=0.1")
    ax.plot(fields_B1['Time'], fields_B1[label]**2, label="B0=1")

    #ax.plot(fields['Time'][0:200], 1*np.exp(2*0.4*fields['Time'])[0:200], label=r"$1*e^{(2*0.4*t)}$")
    ax.set_title(label+r"$^2$")
    ax.legend()
    ax.set_xlabel("t")
    ax.set_ylabel("fld_ene")
    ax.grid()
    plt.yscale('log')
    plt.show()

# %%
80**3
