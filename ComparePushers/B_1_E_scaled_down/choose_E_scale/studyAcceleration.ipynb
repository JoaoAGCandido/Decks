# %%
import osiris_utils as ou
import numpy as np
from pathlib import Path
from tqdm import tqdm
import h5py
import sys
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
#sim_Boris_0_01 = ou.Simulation("/home/exxxx5/Tese/Decks/ComparePushers/B_1_E_scaled_down/Boris/Boris_0_01/Boris_0_01.in")
sim_Boris_0_1 = ou.Simulation("/home/exxxx5/Tese/Decks/ComparePushers/B_1_E_scaled_down/Boris/Boris_0_1/Boris_0_1.in")
sim_Boris_1 = ou.Simulation("/home/exxxx5/Tese/Decks/ComparePushers/B_1_E_scaled_down/Boris/Boris_1/Boris_1.in")
sim_Boris_10 = ou.Simulation("/home/exxxx5/Tese/Decks/ComparePushers/B_1_E_scaled_down/Boris/Boris_10/Boris_10.in")

sim_Boris_0_1E_1 = ou.Simulation("/home/exxxx5/Tese/Decks/ComparePushers/B_1_E_scaled_down/choose_E_scale/Boris_0_1E_1/Boris_0_1E_1.in")

sim_dt0_28SolverOff= ou.Simulation("/home/exxxx5/Tese/Decks/ComparePushers/B_1_E_scaled_down/choose_E_scale/dt0.28SolverOff/Boris_1.in")

# %%
def plot_hist(track, t=-1, mask = False, fig=None, ax=None):
    if fig is None or ax is None:
        fig, ax = plt.subplots()
    
    label = ("$t = {:.2f}$".format(track["t"][0, t]) + "$[{}]$".format(track.units["t"]))

    data = track["p3"][:,t]
    if mask:
        mask = (data < 1) & (data > -1)
        data = data[mask]

    ax.hist(data, bins=50, label=label)
    ax.set_xlabel("${}$".format(track.labels["p3"]) + "$[{}]$".format(track.units["p3"]))

    plt.legend()

    return fig, ax

# %%
# sim_dt0_28SolverOff["test_electrons"]["tracks"].load_all()

# %%
fig, ax = None, None
fig, ax = plot_hist(sim_Boris_0_1["test_electrons"]["tracks"], t=-1, fig=fig, ax=ax)
ax.set_title(r"Boris, $2\pi dt w\_{ce} = 0.1$")
plt.show()

# %%
fig, ax = None, None
fig, ax = plot_hist(sim_Boris_1["test_electrons"]["tracks"], t=-1, fig=fig, ax=ax)
ax.set_title(r"Boris, $2\pi dt w\_{ce} = 1$")
plt.show()

# %%
fig, ax = None, None
fig, ax = plot_hist(sim_Boris_10["test_electrons"]["tracks"], t=-1, fig=fig, ax=ax)
ax.set_title(r"Boris, $2\pi dt w\_{ce} = 10$")
plt.show()
