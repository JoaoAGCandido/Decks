# %%
import osiris_utils as ou
import numpy as np

# %%
# raw = ou.OsirisRawFile("/home/exxxx5/Tese/Decks/ImproveGcaCorr/MHD_BG/GcaCorr/dtw100/MS/RAW/test_electrons/RAW-test_electrons-000000.h5")
# raw.raw_to_file_tags("/home/exxxx5/Tese/Decks/ImproveGcaCorr/MHD_BG/GcaCorr/dtw100/tag_file_MHD.tag")

# %%
sim_weibel = ou.Simulation("/home/exxxx5/Tese/Decks/ImproveGcaCorr/E0_01L400HOT_FinalV/Boris/dtw10/Boris.in")
b1 = sim_weibel["part_b1"]
print("<B1>", np.average(b1[0], axis=(0, 1, 2)) )

# %%
sim=ou.Simulation("/home/exxxx5/Tese/Decks/ImproveGcaCorr/MHD_BG/GcaCorr/dtw100/GcaCorr.in")

b1=sim["part_b1"]
b2=sim["part_b2"]
b3=sim["part_b3"]

# %%
print("<B1>", np.average(b1[0], axis=(0, 1, 2)) )
print("<B2>", np.average(b2[0], axis=(0, 1, 2)) )
print("<B3>", np.average(b3[0], axis=(0, 1, 2)) )

# %%
fig, ax = b1.plot_3d(0, scale_type="zero_centered", boundaries=[[0, 20], [20, 40], [0, 20]])
fig, ax = b2.plot_3d(0, scale_type="zero_centered", boundaries=[[0, 20], [20, 40], [0, 20]])
fig, ax = b3.plot_3d(0, scale_type="zero_centered", boundaries=[[0, 20], [20, 40], [0, 20]])
